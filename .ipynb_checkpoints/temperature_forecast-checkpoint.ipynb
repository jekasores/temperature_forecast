# %% [markdown]
# ## 1) Import libraries <a class="anchor" id="import-lib"></a>

# %%
import numpy as np
import pandas as pd
import collections #used to count frequency of elements in a list
from eda_functions import *

#displays the output inline
# %matplotlib inline

#visualization libraries
import matplotlib.pyplot as plt
import seaborn as sns

#modeling
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_squared_error

# %% [markdown]
# ## 2) Read the dataset <a class="anchor" id="read-dataset"></a>

# %%
df = pd.read_csv("./dataset/Bias_correction_ucl.csv")
df.head()
# Out:
#    station        Date  Present_Tmax  Present_Tmin  LDAPS_RHmin  LDAPS_RHmax  \
# 0      1.0  2013-06-30          28.7          21.4    58.255688    91.116364
# 1      2.0  2013-06-30          31.9          21.6    52.263397    90.604721
# 2      3.0  2013-06-30          31.6          23.3    48.690479    83.973587
# 3      4.0  2013-06-30          32.0          23.4    58.239788    96.483688
# 4      5.0  2013-06-30          31.4          21.9    56.174095    90.155128
#
#    LDAPS_Tmax_lapse  LDAPS_Tmin_lapse  LDAPS_WS    LDAPS_LH  ...  LDAPS_PPT2  \
# 0         28.074101         23.006936  6.818887   69.451805  ...         0.0
# 1         29.850689         24.035009  5.691890   51.937448  ...         0.0
# 2         30.091292         24.565633  6.138224   20.573050  ...         0.0
# 3         29.704629         23.326177  5.650050   65.727144  ...         0.0
# 4         29.113934         23.486480  5.735004  107.965535  ...         0.0
#
#    LDAPS_PPT3  LDAPS_PPT4      lat      lon       DEM   Slope  \
# 0         0.0         0.0  37.6046  126.991  212.3350  2.7850
# 1         0.0         0.0  37.6046  127.032   44.7624  0.5141
# 2         0.0         0.0  37.5776  127.058   33.3068  0.2661
# 3         0.0         0.0  37.6450  127.022   45.7160  2.5348
# 4         0.0         0.0  37.5507  127.135   35.0380  0.5055
#
#    Solar radiation  Next_Tmax  Next_Tmin
# 0      5992.895996       29.1       21.2
# 1      5869.312500       30.5       22.5
# 2      5863.555664       31.1       23.9
# 3      5856.964844       31.7       24.3
# 4      5859.552246       31.2       22.5
#
# [5 rows x 25 columns]

# %% [markdown]
# ## 3) Exploratory Data Analysis <a class="anchor" id="eda"></a>

# %% [markdown]
# ### 3.1) General information

# %%
df_dimensions(df)
# Out:
# The dataframe has 7752 rows and 25 columns

# %% [markdown]
# ### 3.2) Missing values

# %%
cols_missing_values(df)
# Out:
# There are 20 from 25 columns with missing values
# Columns with no missing values =  {'LDAPS_RHmin', 'LDAPS_CC3', 'Next_Tmax', 'Present_Tmax', 'LDAPS_Tmin_lapse', 'LDAPS_CC1', 'LDAPS_PPT2', 'Present_Tmin', 'LDAPS_CC2', 'LDAPS_WS', 'LDAPS_PPT1', 'LDAPS_PPT4', 'LDAPS_LH', 'Next_Tmin', 'Date', 'LDAPS_RHmax', 'LDAPS_CC4', 'station', 'LDAPS_Tmax_lapse', 'LDAPS_PPT3'}

# %%
#Checking if there is a large percentage of missing data
most_missing_values(df, .75)
# Out:
# There are 0 from 25 columns with  more than 75.0% of missing values
# Columns more than 75.0% of values missing =
# set()

# %%
#Checking if there is a large percentage of missing data
most_missing_values(df, .5)
# Out:
# There are 0 from 25 columns with  more than 50.0% of missing values
# Columns more than 50.0% of values missing =
# set()

# %%
#Checking in detail the percentage of missing data
df.isnull().mean()*100
# Out:
# station             0.025800
# Date                0.025800
# Present_Tmax        0.902993
# Present_Tmin        0.902993
# LDAPS_RHmin         0.967492
# LDAPS_RHmax         0.967492
# LDAPS_Tmax_lapse    0.967492
# LDAPS_Tmin_lapse    0.967492
# LDAPS_WS            0.967492
# LDAPS_LH            0.967492
# LDAPS_CC1           0.967492
# LDAPS_CC2           0.967492
# LDAPS_CC3           0.967492
# LDAPS_CC4           0.967492
# LDAPS_PPT1          0.967492
# LDAPS_PPT2          0.967492
# LDAPS_PPT3          0.967492
# LDAPS_PPT4          0.967492
# lat                 0.000000
# lon                 0.000000
# DEM                 0.000000
# Slope               0.000000
# Solar radiation     0.000000
# Next_Tmax           0.348297
# Next_Tmin           0.348297
# dtype: float64

# %% [markdown]
# - Considering that the columns with missing values have less than 1% of missing data it will be easier to drop the rows with missing values

# %%
df = df.dropna(axis=0)

# %%
df_dimensions(df)
# Out:
# The dataframe has 7588 rows and 25 columns

# %%
#Checking in detail the percentage of missing data
df.isnull().mean()*100
# Out:
# station             0.0
# Date                0.0
# Present_Tmax        0.0
# Present_Tmin        0.0
# LDAPS_RHmin         0.0
# LDAPS_RHmax         0.0
# LDAPS_Tmax_lapse    0.0
# LDAPS_Tmin_lapse    0.0
# LDAPS_WS            0.0
# LDAPS_LH            0.0
# LDAPS_CC1           0.0
# LDAPS_CC2           0.0
# LDAPS_CC3           0.0
# LDAPS_CC4           0.0
# LDAPS_PPT1          0.0
# LDAPS_PPT2          0.0
# LDAPS_PPT3          0.0
# LDAPS_PPT4          0.0
# lat                 0.0
# lon                 0.0
# DEM                 0.0
# Slope               0.0
# Solar radiation     0.0
# Next_Tmax           0.0
# Next_Tmin           0.0
# dtype: float64

# %%
#Calculating the percentage of data removed after droping rows with missing data
#For this purpose the result of the function df_dimensions() was used before and after dropping the rows with missing data
(7752 -7588)/7752 *100
# Out:
# 2.1155830753353975

# %% [markdown]
# - The rows with missing values were droped successfully and 2% of the data was lost in this process

# %% [markdown]
# ### 3.3) Categorical variables

# %%
categorical_cols(df)
# Out:
# There are 1 from 25 columns with categorical data
# Columns categorical data =  ['Date']

# %% [markdown]
# ### 3.4) Numerical variables

# %%
numerical_cols(df)
# Out:
# There are 24 from 25 columns with numerical data
# Columns numerical data =  ['station', 'Present_Tmax', 'Present_Tmin', 'LDAPS_RHmin', 'LDAPS_RHmax', 'LDAPS_Tmax_lapse', 'LDAPS_Tmin_lapse', 'LDAPS_WS', 'LDAPS_LH', 'LDAPS_CC1', 'LDAPS_CC2', 'LDAPS_CC3', 'LDAPS_CC4', 'LDAPS_PPT1', 'LDAPS_PPT2', 'LDAPS_PPT3', 'LDAPS_PPT4', 'lat', 'lon', 'DEM', 'Slope', 'Solar radiation', 'Next_Tmax', 'Next_Tmin']

# %%
df.describe()
# Out:
#            station  Present_Tmax  Present_Tmin  LDAPS_RHmin  LDAPS_RHmax  \
# count  7588.000000   7588.000000   7588.000000  7588.000000  7588.000000
# mean     13.014101     29.748366     23.195809    56.724969    88.360823
# std       7.217858      2.967401      2.400880    14.626559     7.199456
# min       1.000000     20.000000     11.300000    19.794666    58.936283
# 25%       7.000000     27.800000     21.600000    45.960243    84.203724
# 50%      13.000000     29.900000     23.400000    55.023199    89.784122
# 75%      19.000000     32.000000     24.800000    67.115099    93.742725
# max      25.000000     37.600000     29.900000    98.524734   100.000153
#
#        LDAPS_Tmax_lapse  LDAPS_Tmin_lapse     LDAPS_WS     LDAPS_LH  \
# count       7588.000000       7588.000000  7588.000000  7588.000000
# mean          29.620128         23.511786     7.094097    62.492606
# std            2.943496          2.342579     2.177034    33.686158
# min           17.624954         14.272646     2.882580   -13.603212
# 25%           27.673756         22.086820     5.675358    37.206201
# 50%           29.709537         23.758249     6.547838    56.898324
# 75%           31.711109         25.155660     8.028960    84.235666
# max           38.542255         29.619342    21.857621   213.414006
#
#          LDAPS_CC1  ...   LDAPS_PPT2   LDAPS_PPT3   LDAPS_PPT4          lat  \
# count  7588.000000  ...  7588.000000  7588.000000  7588.000000  7588.000000
# mean      0.368510  ...     0.480738     0.275007     0.265373    37.544792
# std       0.262260  ...     1.743327     1.146087     1.179661     0.050428
# min       0.000000  ...     0.000000     0.000000     0.000000    37.456200
# 25%       0.146546  ...     0.000000     0.000000     0.000000    37.510200
# 50%       0.315706  ...     0.000000     0.000000     0.000000    37.550700
# 75%       0.574174  ...     0.017735     0.007855     0.000017    37.577600
# max       0.967277  ...    21.621661    15.841235    16.655469    37.645000
#
#               lon          DEM        Slope  Solar radiation    Next_Tmax  \
# count  7588.00000  7588.000000  7588.000000      7588.000000  7588.000000
# mean    126.99142    61.918136     1.259755      5343.724208    30.241526
# std       0.07922    54.323529     1.372748       429.782561     3.111807
# min     126.82600    12.370000     0.098500      4329.520508    17.400000
# 25%     126.93700    28.700000     0.271300      5001.485717    28.200000
# 50%     126.99500    45.716000     0.618000      5441.987305    30.400000
# 75%     127.04200    59.832400     1.767800      5729.485840    32.600000
# max     127.13500   212.335000     5.178200      5992.895996    38.900000
#
#          Next_Tmin
# count  7588.000000
# mean     22.910820
# std       2.482256
# min      11.300000
# 25%      21.300000
# 50%      23.100000
# 75%      24.600000
# max      29.800000
#
# [8 rows x 24 columns]

# %%
df.hist(figsize = (14,12));

# %%
fig, ax = plt.subplots(figsize=(15,15)) 
sns.heatmap(df.corr(), annot=True, fmt=".2f")
